# %% [markdown]
# ---
# title: "CSW Test Formal-Run"
# subtitle: "CSW-Formal-Run contributed a notebook to the Notebook Gallery"
# author: "Author: CSW-test"
# tags: [CSW-Formal-Run, Template]
# thumbnail: img/test-image-csw.png
# license: MIT
# copyright: "© 2024 EUMETSAT"
# ---
#
# <div style="margin: 6px 0;">
#   <a href="https://jupyter.central.data.destination-earth.eu/user-redirect/lab/tree/CSW-test-formal-run.ipynb" target="_blank" style="text-decoration: none;">
#     <span class="launch">🚀 Launch in JupyterHub</span>
#   </a>
# </div>

# %% [markdown]
# # CSW Test Formal-Run
#
# This notebook demonstrates the contribution workflow to the Notebook Gallery.
#
# - [Contents](#CSW-test-formal-run.ipynb-Contents)
# - [Prerequisites](#CSW-test-formal-run.ipynb-Prerequisites)

# %% [markdown]
# (CSW-test-formal-run.ipynb-Contents)=
# ## Contents
#
# This notebook demonstrates a simple structure following the required template for the Notebook Gallery contribution process.
#
# - **Objective:** Verify that users can upload, get approval for, launch, run, and delete custom notebooks using the Notebook Gallery.
# - **Data Sources:** Inline Python list.
# - **Methods:** Basic Python list operations to count items.
# - **Prerequisites:** Python 3, no external libraries needed.
# - **Expected Output:** A printed integer representing the number of apples in a sample dataset.

# %% [markdown]
# (CSW-test-formal-run.ipynb-Prerequisites)=
# ## Prerequisites
#
# This section was inspired by [this template](https://github.com/alan-turing-institute/the-turing-way/blob/master/book/templates/chapter-template/chapter-landing-page.md) of the wonderful [The Turing Way](https://the-turing-way.netlify.app) Jupyter Book.
#
# No special packages or credentials are required for this notebook.

# %% [markdown]
# ## Imports
#
# This notebook uses only standard Python libraries.

# %%
import sys

# %% [markdown]
# ## Getting Started
#
# We begin with a simple example to verify the notebook runs correctly.

# %%
print("Hello world!")

# %% [markdown]
# ### Basic List Operations
#
# Let's demonstrate some basic Python list operations.

# %%
a = [1, 2, 3, 4, 5]
[i + 2 for i in a]

# %% [markdown]
# ### Counting Items in a List
#
# Now we demonstrate the main objective: counting specific items in a dataset.

# %%
fruits = ['apple', 'banana', 'apple', 'orange', 'apple']
apple_count = fruits.count('apple')
print(f"Number of apples: {apple_count}")
apple_count

# %% [markdown]
# ## Verification Results
#
# The notebook has successfully executed all operations, demonstrating the contribution workflow.

# %% [markdown]
# ## Summary
#
# This notebook demonstrates the structured template for contributing to the Notebook Gallery and performs a simple test counting apples in a dataset. The key takeaway is how to follow the template structure while keeping code sections clean and organized for gallery contributions.

# %% [markdown]
# ## Resources and References
#
# - [The Turing Way Jupyter Book](https://the-turing-way.netlify.app)
# - [Python Documentation](https://docs.python.org)
# - [DestinE DataLake Notebook Gallery](https://destination-earth.github.io/DestinE-DataLake-Gallery/)
#
# **Thank you for your contribution!**
